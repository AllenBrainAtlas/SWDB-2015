# %%
import numpy as np
import os

dir = r'C:\Data\FHL2015\SWDB-2015\presentations\celltypes\ccf_sholl\morphology\morphology_354190013'
fname = os.path.join(dir,'apical_dendrite.npy')
ad = np.load(fname)

fname = os.path.join(dir,'basal_dendrite.npy')
bd = np.load(fname)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(ad,color='magenta')
plt.plot(bd,color='green')
